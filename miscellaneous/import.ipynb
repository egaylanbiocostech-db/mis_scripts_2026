# %%
import pandas as pd, numpy as np, sqlalchemy as sqla, shutil, decouple
from sqlalchemy import Integer, String, Float, DECIMAL
from IPython.display import display
import re
pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", "{:.2f}".format)

# local_engine = sqla.create_engine("mysql+pymysql://root:1234@localhost:3306")
engine = sqla.create_engine(decouple.config("MIS_DASHBOARD"))
# mis_file_path = decouple.config("MIS_FILE_PATH")
# red_engine = sqla.create_engine("mysql+mysqlconnector://mis-zedrick:zedrick123@120.28.99.16:3306")

# %%
product_list = pd.read_excel(r"C:\eli_dump\anwell_test\test1v1.xlsx")

# %%
product_list.head(10)
# Out:
#                                  product_description     product_code  \
# 0                                    Aera Collagen C  Aera Collagen C
# 1  iWhite Korea 2 Minute Whitening Miracle Gel - ...              2MS
# 2  iWhite Korea 2 Minute Whitening Miracle Gel - ...         2MS 24's
# 3  iWhite Korea 2 Minute Whitening Miracle Gel - ...              2MT
# 4    Aera Glow White Food Supplement Softgel Capsule  Aera Glow White
# 5        Aera Aura Water Sunscreen SPF50 35ml (AAWB)             AAWB
# 6    Aera BB Sun Tint SPF30 Light Sachet 4ml (ABBLS)            ABBLS
# 7  Aera BB Sun Tint SPF30 Light - 4ml Box of 24's...       ABBLS 24's
# 8     Aera BB Sun Tint SPF30 Light Tube 25ml (ABBLT)            ABBLT
# 9  Aera BB Sun Tint SPF30 Natural Sachet 4ml (ABBNS)            ABBNS
#
#   product_category product_type  year_launch        status            brand  \
# 0      Supplements     NPI 2023         2023  Discontinued         Nutribio
# 1        Pore Care      Regular         2000  Discontinued     iWhite Korea
# 2        Pore Care      Regular         2000  Discontinued     iWhite Korea
# 3        Pore Care      Regular         2000  Discontinued     iWhite Korea
# 4      Supplements     NPI 2023         2023  Discontinued         Nutribio
# 5        Sunscreen     NPI 2023         2022        Active      Aera x Bela
# 6         BB Cream     NPI 2022         2022        Active  Aera Essentials
# 7         BB Cream     NPI 2022         2022        Active  Aera Essentials
# 8         BB Cream     NPI 2022         2022  Discontinued  Aera Essentials
# 9         BB Cream     NPI 2022         2022        Active  Aera Essentials
#
#   packaging
# 0       Box
# 1    Sachet
# 2    Sachet
# 3      Tube
# 4       Box
# 5      Tube
# 6    Sachet
# 7    Sachet
# 8      Tube
# 9    Sachet

# %%
product_list.to_sql(
    name="product_list",
    con=engine,
    schema="dashboard-sales",
    if_exists="append",
    index=False,
    chunksize=1000,
    method="multi"
)
# Out:
# 363

# %%
# # universe_of_accounts = pd.read_excel(r"C:\Users\bioco\Documents\mis-py\dashboard_universe.xlsx")
# universe_of_accounts = pd.read_excel(r"C:\eli_dump\Backup\Database Files\Universe\Dashboard_Universe.xlsx")
# display(universe_of_accounts.head(1))

# %%
# from sqlalchemy import Table, Column, MetaData, String

# metadata = MetaData()
# tbl = Table(
#     "overall_universe_accounts",
#     metadata,
#     Column("bpc_store_code",               String(255), nullable=False, primary_key=True),
#     Column("store_code",                   String(255), nullable=True),
#     Column("account_code",                 String(255), nullable=True),
#     Column("account_chain_name",                 String(255), nullable=True),
#     Column("account_store_name",                String(255), nullable=True),
#     Column("city",                         String(255), nullable=True),
#     Column("province",                     String(255), nullable=True),
#     Column("region",                       String(255), nullable=True),
#     Column("bpc_region",                   String(255), nullable=True),
#     Column("account_tas",           String(255), nullable=True),
#     Column("account_merchandiser",  String(255), nullable=True),
#     schema="redreport2026",
# )

# with engine.connect() as conn:
#     conn.execute(sqla.text("TRUNCATE `redreport2026`.`overall_universe_accounts`"))
#     conn.commit()

# universe_of_accounts.to_sql(
#     name="overall_universe_accounts",
#     con=engine,
#     schema="redreport2026",
#     if_exists="replace",
#     index=False,
#     chunksize=1000,
#     dtype={
#         "bpc_store_code":               String(255),
#         "store_code":                   String(255),
#         "account_code":                 String(255),
#         "account_chain_name":                 String(255),
#         "account_store_name":                String(255),
#         "city":                         String(255),
#         "province":                     String(255),
#         "region":                       String(255),
#         "bpc_region":                   String(255),
#         "account_tas":           String(255),
#         "account_merchandiser":  String(255),
#     },
#     method="multi"
# )

# %%
# from sqlalchemy import Table, Column, MetaData, String

# metadata = MetaData()
# tbl = Table(
#     "universe_of_accounts",
#     metadata,
#     Column("bpc_store_code",               String(255), nullable=False, primary_key=True),
#     Column("store_code",                   String(255), nullable=False),
#     Column("account_code",                 String(255), nullable=False),
#     Column("account_name",                 String(255), nullable=False),
#     Column("account_chain",                String(255), nullable=False),
#     Column("store_name",                   String(255), nullable=False),
#     Column("city",                         String(255), nullable=True),
#     Column("province",                     String(255), nullable=True),
#     Column("region",                       String(255), nullable=True),
#     Column("bpc_region",                   String(255), nullable=False),
#     Column("asl_plantilla_code",           String(255), nullable=True),
#     Column("kas_plantilla_code",           String(255), nullable=True),
#     Column("merchandiser_plantilla_code",  String(255), nullable=True),
#     schema="dashboard-sales",
# )

# with engine.connect() as conn:
#     conn.execute(sqla.text("TRUNCATE TABLE `dashboard-sales`.`universe_of_accounts`"))
#     conn.commit()

# universe_of_accounts.to_sql(
#     name="universe_of_accounts",
#     con=engine,
#     schema="dashboard-sales",
#     if_exists="append",
#     index=False,
#     chunksize=1000,
#     dtype={
#         "bpc_store_code":               String(255),
#         "store_code":                   String(255),
#         "account_code":                 String(255),
#         "account_name":                 String(255),
#         "account_chain":                String(255),
#         "store_name":                   String(255),
#         "city":                         String(255),
#         "province":                     String(255),
#         "region":                       String(255),
#         "bpc_region":                   String(255),
#         "asl_plantilla_code":           String(255),
#         "kas_plantilla_code":           String(255),
#         "merchandiser_plantilla_code":  String(255),
#     },
#     method="multi"
# )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 27
#      24     conn.execute(sqla.text("TRUNCATE TABLE `dashboard-sales`.`universe_of_accounts`"))
#      25     conn.commit()
# ---> 27 universe_of_accounts.to_sql(
#      28     name="universe_of_accounts",
#      29     con=engine,
#      30     schema="dashboard-sales",
#      31     if_exists="append",
#      32     index=False,
#      33     chunksize=1000,
#      34     dtype={
#      35         "bpc_store_code":               String(255),
#      36         "store_code":                   String(255),
#      37         "account_code":                 String(255),
#      38         "account_name":                 String(255),
#      39         "account_chain":                String(255),
#      40         "store_name":                   String(255),
#      41         "city":                         String(255),
#      42         "province":                     String(255),
#      43         "region":                       String(255),
#      44         "bpc_region":                   String(255),
#      45         "asl_plantilla_code":           String(255),
#      46         "kas_plantilla_code":           String(255),
#      47         "merchandiser_plantilla_code":  String(255),
#      48     },
#      49     method="multi"
#      50 )
#
# NameError: name 'universe_of_accounts' is not defined
