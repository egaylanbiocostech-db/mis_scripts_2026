# %%
import pandas as pd, sqlalchemy as sqla
from sqlalchemy import BigInteger, String

#                                         "mysql+pymysql://username:password@hostname:port"
web_dashboard_engine = sqla.create_engine("mysql+pymysql://mis-data-analyst:%40MISanalyst2026@wms-files.bpc-red-report.com:3306")

# %%
employees_table = pd.read_sql("SELECT * FROM `dashboard-sales`.employees", web_dashboard_engine)

employees_table.head()
# Out:
#    id employee_name plantilla_code department position
# 0   1   Tina Madjus     TOS-NCR-01      Sales      TOS
# 1   2   Allan Acala     TOS-NCR-02      Sales      TOS
# 2   3        Vacant     TOS-NCR-03      Sales      TOS
# 3   4        Vacant     TOS-NCR-04      Sales      TOS
# 4   5        Vacant     TOS-CAR-01      Sales      TOS

# %%
little_black_book = pd.read_csv(r"C:\eli_dump\Backup\Database Files\Dashboard Database\little_black_book.csv")
little_black_book.head()

little_black_book.to_sql(
    name="little_black_book",
    con=web_dashboard_engine,
    schema="dashboard-sales",
    if_exists="replace",
    index=False,
    chunksize=1000,
    dtype={
        "id":                     BigInteger(),
        "account_name":           String(255),
        "account_chain":          String(255),
        "account_type":           String(255),
        "account_channel":        String(255),
        "channel_class":          String(255),
        "business_unit":          String(255),
        "bpc_region":             String(255),
        "manager_plantilla_code": String(255),
        "report_group":           String(255),
    }
)
# Out:
# 2157
